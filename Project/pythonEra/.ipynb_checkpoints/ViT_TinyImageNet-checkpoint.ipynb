# %% [markdown]
# # Tiny ImageNet ViT (PyTorch + timm)
#
# This notebook implements a custom ~1 Million parameter Vision Transformer for Tiny ImageNet (64x64).
#
# **Architecture:**
# * **Library:** `timm` (PyTorch Image Models)
# * **Input:** 64x64 images
# * **Patch Size:** 8
# * **Dim:** 96 (Embedding dimension)
# * **Depth:** 8 layers
# * **Heads:** 4
# * **Params:** ~930k (Fits the 750k-1M requirement)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import timm
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import requests
import zipfile
import io
import torchinfo
from torchinfo import summary
from PIL import Image

# Setup Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## 2. Data Preparation
# Tiny ImageNet validation folder needs formatting to work with PyTorch `ImageFolder`.

# %%
DATA_DIR = './tiny-imagenet-200'

def download_and_format_tiny_imagenet(root_dir):
    # 1. Download if not exists
    url = "http://cs231n.stanford.edu/tiny-imagenet-200.zip"
    if not os.path.exists(root_dir):
        print("Downloading Tiny ImageNet...")
        r = requests.get(url)
        z = zipfile.ZipFile(io.BytesIO(r.content))
        z.extractall('./')
        print("Extracted.")
    else:
        print("Dataset already exists.")

    # 2. Format Validation Set (Move images into class folders)
    val_dir = os.path.join(root_dir, 'val')
    val_img_dir = os.path.join(val_dir, 'images')
    val_annotations = os.path.join(val_dir, 'val_annotations.txt')
    
    # Check if already formatted
    if os.path.exists(val_img_dir) and len(os.listdir(val_img_dir)) > 0:
        print("Formatting validation set...")
        with open(val_annotations, 'r') as f:
            for line in f:
                parts = line.split('\t')
                img_name = parts[0]
                class_label = parts[1]
                
                # Create class folder if not exists
                class_folder = os.path.join(val_dir, class_label)
                if not os.path.exists(class_folder):
                    os.makedirs(class_folder)
                
                # Move image
                src = os.path.join(val_img_dir, img_name)
                dst = os.path.join(class_folder, img_name)
                if os.path.exists(src):
                    os.rename(src, dst)
        
        # Cleanup empty images folder
        if not os.listdir(val_img_dir):
             os.rmdir(val_img_dir)
        print("Validation set formatted.")
    else:
        print("Validation set already formatted.")

download_and_format_tiny_imagenet(DATA_DIR)
# Out:
# Dataset already exists.
# Validation set already formatted.

# %% [markdown]
# ## 3. Dataloaders
# We use Patch Size 8, so input is 64x64.

# %%
BATCH_SIZE = 128
NUM_WORKERS = 2

# Augmentations
train_transform = transforms.Compose([
    transforms.RandomCrop(64, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.2, 0.2, 0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# Datasets
train_ds = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_ds = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_transform)

# Loaders
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print(f"Training classes: {len(train_ds.classes)}")
print(f"Training samples: {len(train_ds)}")
# Out:
# Training classes: 200
# Training samples: 100000

# %% [markdown]
# ## 4. Define Custom ViT Model (~1M Params)
# We use `timm` to create a "Micro" ViT.
# * **Embed Dim:** 96
# * **Depth:** 8
# * **Heads:** 4
# * **Patch Size:** 8

# %%
model = timm.models.vision_transformer.VisionTransformer(
    img_size=64,
    patch_size=8,
    in_chans=3,
    num_classes=200,
    embed_dim=96,    # Kept small to reduce params
    depth=8,         # 8 layers
    num_heads=4,     # 4 heads
    mlp_ratio=2.0,   # Reduced MLP ratio
    qkv_bias=True,
)

model = model.to(device)

# Count parameters
param_count = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Model Parameters: {param_count / 1e6:.2f} Million")
# Out:
# Model Parameters: 0.64 Million

# %% [markdown]
# ## 5. Training Loop
# Using AdamW and Cosine Annealing.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.05)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=30)

num_epochs = 30
train_accs, val_accs = [], []
train_losses, val_losses = [], []

print("Starting training...")
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
    for images, labels in pbar:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        
        pbar.set_postfix({'loss': running_loss/len(train_loader)})
    
    train_acc = 100 * correct / total
    train_loss = running_loss / len(train_loader)
    
    # Validation
    model.eval()
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            val_running_loss += loss.item()
            _, predicted = outputs.max(1)
            val_total += labels.size(0)
            val_correct += predicted.eq(labels).sum().item()
            
    val_acc = 100 * val_correct / val_total
    val_loss = val_running_loss / len(val_loader)
    
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    scheduler.step()
    
    print(f"Ep {epoch+1}: Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.4f}")
# Out:
# Starting training...
# Epoch 1/30: 100%|██████████████████| 782/782 [01:12<00:00, 10.84it/s, loss=4.78]
# Ep 1: Train Acc: 4.86% | Val Acc: 9.04% | Val Loss: 4.4114
# Epoch 2/30: 100%|██████████████████| 782/782 [01:00<00:00, 12.99it/s, loss=4.24]
# Ep 2: Train Acc: 11.01% | Val Acc: 13.10% | Val Loss: 4.0567
# Epoch 3/30: 100%|██████████████████| 782/782 [01:00<00:00, 12.85it/s, loss=3.95]
# Ep 3: Train Acc: 14.77% | Val Acc: 16.60% | Val Loss: 3.7933
# Epoch 4/30: 100%|██████████████████| 782/782 [01:01<00:00, 12.81it/s, loss=3.75]
# Ep 4: Train Acc: 17.84% | Val Acc: 20.40% | Val Loss: 3.6081
# Epoch 5/30: 100%|██████████████████| 782/782 [01:00<00:00, 13.00it/s, loss=3.59]
# Ep 5: Train Acc: 20.39% | Val Acc: 22.16% | Val Loss: 3.4680
# Epoch 6/30: 100%|██████████████████| 782/782 [01:00<00:00, 12.95it/s, loss=3.45]
# Ep 6: Train Acc: 22.63% | Val Acc: 23.40% | Val Loss: 3.3917
# Epoch 7/30: 100%|██████████████████| 782/782 [00:59<00:00, 13.07it/s, loss=3.32]
# Ep 7: Train Acc: 24.60% | Val Acc: 24.98% | Val Loss: 3.2842
# Epoch 8/30: 100%|██████████████████| 782/782 [01:00<00:00, 12.95it/s, loss=3.21]
# Ep 8: Train Acc: 26.70% | Val Acc: 26.54% | Val Loss: 3.2363
# Epoch 9/30: 100%|███████████████████| 782/782 [01:00<00:00, 12.94it/s, loss=3.1]
# Ep 9: Train Acc: 28.64% | Val Acc: 27.91% | Val Loss: 3.1289
# Epoch 10/30: 100%|████████████████████| 782/782 [01:00<00:00, 12.85it/s, loss=3]
# Ep 10: Train Acc: 30.33% | Val Acc: 29.52% | Val Loss: 3.0393
# Epoch 11/30: 100%|█████████████████| 782/782 [01:00<00:00, 13.02it/s, loss=2.91]
# Ep 11: Train Acc: 31.80% | Val Acc: 31.39% | Val Loss: 2.9692
# Epoch 12/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.12it/s, loss=2.83]
# Ep 12: Train Acc: 33.49% | Val Acc: 31.63% | Val Loss: 2.9461
# Epoch 13/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.23it/s, loss=2.75]
# Ep 13: Train Acc: 34.94% | Val Acc: 33.32% | Val Loss: 2.8617
# Epoch 14/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.24it/s, loss=2.68]
# Ep 14: Train Acc: 36.06% | Val Acc: 33.78% | Val Loss: 2.8591
# Epoch 15/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.20it/s, loss=2.62]
# Ep 15: Train Acc: 37.46% | Val Acc: 34.24% | Val Loss: 2.8146
# Epoch 16/30: 100%|█████████████████| 782/782 [00:58<00:00, 13.30it/s, loss=2.56]
# Ep 16: Train Acc: 38.52% | Val Acc: 35.20% | Val Loss: 2.7742
# Epoch 17/30: 100%|██████████████████| 782/782 [00:59<00:00, 13.17it/s, loss=2.5]
# Ep 17: Train Acc: 39.75% | Val Acc: 35.34% | Val Loss: 2.7648
# Epoch 18/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.06it/s, loss=2.45]
# Ep 18: Train Acc: 40.77% | Val Acc: 36.24% | Val Loss: 2.7286
# Epoch 19/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.11it/s, loss=2.39]
# Ep 19: Train Acc: 42.07% | Val Acc: 36.65% | Val Loss: 2.7124
# Epoch 20/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.15it/s, loss=2.34]
# Ep 20: Train Acc: 42.99% | Val Acc: 36.93% | Val Loss: 2.6953
# Epoch 21/30: 100%|█████████████████| 782/782 [00:58<00:00, 13.30it/s, loss=2.29]
# Ep 21: Train Acc: 44.02% | Val Acc: 37.55% | Val Loss: 2.6864
# Epoch 22/30: 100%|█████████████████| 782/782 [01:00<00:00, 13.01it/s, loss=2.24]
# Ep 22: Train Acc: 44.93% | Val Acc: 37.86% | Val Loss: 2.6735
# Epoch 23/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.12it/s, loss=2.21]
# Ep 23: Train Acc: 45.79% | Val Acc: 38.25% | Val Loss: 2.6549
# Epoch 24/30: 100%|█████████████████| 782/782 [01:00<00:00, 12.96it/s, loss=2.16]
# Ep 24: Train Acc: 46.51% | Val Acc: 38.52% | Val Loss: 2.6508
# Epoch 25/30: 100%|█████████████████| 782/782 [00:58<00:00, 13.42it/s, loss=2.13]
# Ep 25: Train Acc: 47.16% | Val Acc: 39.15% | Val Loss: 2.6376
# Epoch 26/30: 100%|██████████████████| 782/782 [00:59<00:00, 13.14it/s, loss=2.1]
# Ep 26: Train Acc: 47.90% | Val Acc: 38.78% | Val Loss: 2.6425
# Epoch 27/30: 100%|█████████████████| 782/782 [01:00<00:00, 13.02it/s, loss=2.08]
# Ep 27: Train Acc: 48.50% | Val Acc: 38.81% | Val Loss: 2.6364
# Epoch 28/30: 100%|█████████████████| 782/782 [01:03<00:00, 12.34it/s, loss=2.06]
# Ep 28: Train Acc: 48.75% | Val Acc: 39.06% | Val Loss: 2.6350
# Epoch 29/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.12it/s, loss=2.05]
# Ep 29: Train Acc: 49.27% | Val Acc: 39.12% | Val Loss: 2.6369
# Epoch 30/30: 100%|█████████████████| 782/782 [00:59<00:00, 13.06it/s, loss=2.04]
# Ep 30: Train Acc: 49.48% | Val Acc: 39.16% | Val Loss: 2.6330

# %% [markdown]
# ## 6. Visualization (Attention Maps)
# Visualizing the CLS token attention.

# %%
def visualize_attention(model, img, device):
    model.eval()
    
    # Monkey-patch the last layer to capture attention
    last_block = model.blocks[-1].attn
    original_forward = last_block.forward
    
    saved_attn = {}
    def forwarding_hook(x):
        B, N, C = x.shape
        qkv = last_block.qkv(x).reshape(B, N, 3, last_block.num_heads, C // last_block.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv.unbind(0)
        attn = (q @ k.transpose(-2, -1)) * last_block.scale
        attn = attn.softmax(dim=-1)
        saved_attn['map'] = attn
        return original_forward(x)
    
    last_block.forward = forwarding_hook
    
    # Run Inference
    img_tensor = val_transform(img).unsqueeze(0).to(device)
    _ = model(img_tensor)
    
    # Restore
    last_block.forward = original_forward
    
    # Process Map
    attn_map = saved_attn['map'].mean(dim=1).squeeze(0)
    cls_attn = attn_map[0, 1:]
    
    grid_size = int(np.sqrt(cls_attn.shape[0]))
    cls_attn_2d = cls_attn.reshape(grid_size, grid_size).detach().cpu().numpy()
    
    cls_attn_resized = torch.nn.functional.interpolate(
        torch.tensor(cls_attn_2d).unsqueeze(0).unsqueeze(0), 
        size=(64, 64), 
        mode='bilinear'
    ).squeeze().numpy()
    
    # Plot
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    ax[0].imshow(img)
    ax[0].set_title("Original Image")
    ax[0].axis('off')
    
    ax[1].imshow(img, alpha=1)
    ax[1].imshow(cls_attn_resized, cmap='jet', alpha=0.5)
    ax[1].set_title("Attention Map")
    ax[1].axis('off')
    plt.show()

# Run visualization
import random
rand_idx = random.randint(0, len(val_ds))
raw_img = ImageFolder(os.path.join(DATA_DIR, 'val'))[rand_idx][0]
visualize_attention(model, raw_img, device)
# 1. Textual Tree View (Standard PyTorch)
# Shows the nested structure of blocks
print("--- Model Hierarchy ---")
print(model)

# 2. Tabular Summary (Keras-Style)
# Shows layer types, output shapes, and parameter counts per layer
print("\n--- Model Summary Table ---")
summary(model, input_size=(1, 3, 64, 64), 
        col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
        verbose=1)

# %%
# Get validation

def calculate_topk_accuracy(model, dataloader, device, topk=(1, 5, 10)):
    model.eval()
    correct_counts = {k: 0 for k in topk}
    total_samples = 0
    
    # Ensure we look for the max k needed (e.g., top 10)
    max_k = max(topk)
    
    print(f"Evaluating Top-{topk} accuracy...")
    
    with torch.no_grad():
        for images, labels in tqdm(dataloader, desc="Eval"):
            images, labels = images.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(images)
            
            # Get the top k predictions (indices)
            # output shape: [batch_size, num_classes]
            # pred shape: [batch_size, max_k]
            _, pred = outputs.topk(max_k, 1, True, True)
            pred = pred.t() # Transpose to [max_k, batch_size]
            
            # Check if true label is in prediction
            # labels.view(1, -1) expands to [1, batch_size]
            # expand_as(pred) expands to [max_k, batch_size]
            # correct tensor is boolean matrix of [max_k, batch_size]
            correct = pred.eq(labels.view(1, -1).expand_as(pred))
            
            # Update counters
            batch_size = labels.size(0)
            total_samples += batch_size
            
            for k in topk:
                # Sum the correct predictions in the first k rows
                correct_k = correct[:k].reshape(-1).float().sum().item()
                correct_counts[k] += correct_k

    # Print results
    print("\n" + "="*30)
    print("VALIDATION RESULTS")
    print("="*30)
    for k in topk:
        acc = 100 * correct_counts[k] / total_samples
        print(f"Top-{k} Accuracy: {acc:.2f}%")
    print("="*30)
    
    return correct_counts

# Run evaluation
_ = calculate_topk_accuracy(model, val_loader, device)
# Out:
# Evaluating Top-(1, 5, 10) accuracy...
# Eval: 100%|█████████████████████████████████████| 79/79 [00:04<00:00, 19.61it/s]
# ==============================
# VALIDATION RESULTS
# ==============================
# Top-1 Accuracy: 39.16%
# Top-5 Accuracy: 65.54%
# Top-10 Accuracy: 76.01%
# ==============================

# %%
# Export weights
import struct

def export_model_weights(model, filename="nano_vit_weights.bin"):
    model.eval()
    
    print(f"Exporting weights to {filename}...")
    print("-" * 80)
    print(f"{'Layer Name':<40} | {'Shape':<20} | {'Count':<10}")
    print("-" * 80)
    
    with open(filename, "wb") as f:
        total_params = 0
        
        # Iterate through all named parameters (weights + biases)
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
                
            # Convert to numpy float32
            # Note: clone().detach() ensures we don't mess up the graph
            # .cpu() moves it to host memory
            # .numpy() converts to numpy array
            data = param.detach().cpu().numpy().astype(np.float32)
            
            # Write raw bytes
            f.write(data.tobytes())
            
            # Logging
            count = data.size
            total_params += count
            print(f"{name:<40} | {str(list(data.shape)):<20} | {count:<10}")
            
    print("-" * 80)
    print(f"Total Parameters Written: {total_params}")
    print(f"File Size: {os.path.getsize(filename) / 1024:.2f} KB")

# Run the export
export_model_weights(model)
# Out:
# Exporting weights to nano_vit_weights.bin...
# --------------------------------------------------------------------------------
# Layer Name                               | Shape                | Count
# --------------------------------------------------------------------------------
# cls_token                                | [1, 1, 96]           | 96
# pos_embed                                | [1, 65, 96]          | 6240
# patch_embed.proj.weight                  | [96, 3, 8, 8]        | 18432
# patch_embed.proj.bias                    | [96]                 | 96
# blocks.0.norm1.weight                    | [96]                 | 96
# blocks.0.norm1.bias                      | [96]                 | 96
# blocks.0.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.0.attn.qkv.bias                   | [288]                | 288
# blocks.0.attn.proj.weight                | [96, 96]             | 9216
# blocks.0.attn.proj.bias                  | [96]                 | 96
# blocks.0.norm2.weight                    | [96]                 | 96
# blocks.0.norm2.bias                      | [96]                 | 96
# blocks.0.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.0.mlp.fc1.bias                    | [192]                | 192
# blocks.0.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.0.mlp.fc2.bias                    | [96]                 | 96
# blocks.1.norm1.weight                    | [96]                 | 96
# blocks.1.norm1.bias                      | [96]                 | 96
# blocks.1.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.1.attn.qkv.bias                   | [288]                | 288
# blocks.1.attn.proj.weight                | [96, 96]             | 9216
# blocks.1.attn.proj.bias                  | [96]                 | 96
# blocks.1.norm2.weight                    | [96]                 | 96
# blocks.1.norm2.bias                      | [96]                 | 96
# blocks.1.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.1.mlp.fc1.bias                    | [192]                | 192
# blocks.1.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.1.mlp.fc2.bias                    | [96]                 | 96
# blocks.2.norm1.weight                    | [96]                 | 96
# blocks.2.norm1.bias                      | [96]                 | 96
# blocks.2.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.2.attn.qkv.bias                   | [288]                | 288
# blocks.2.attn.proj.weight                | [96, 96]             | 9216
# blocks.2.attn.proj.bias                  | [96]                 | 96
# blocks.2.norm2.weight                    | [96]                 | 96
# blocks.2.norm2.bias                      | [96]                 | 96
# blocks.2.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.2.mlp.fc1.bias                    | [192]                | 192
# blocks.2.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.2.mlp.fc2.bias                    | [96]                 | 96
# blocks.3.norm1.weight                    | [96]                 | 96
# blocks.3.norm1.bias                      | [96]                 | 96
# blocks.3.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.3.attn.qkv.bias                   | [288]                | 288
# blocks.3.attn.proj.weight                | [96, 96]             | 9216
# blocks.3.attn.proj.bias                  | [96]                 | 96
# blocks.3.norm2.weight                    | [96]                 | 96
# blocks.3.norm2.bias                      | [96]                 | 96
# blocks.3.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.3.mlp.fc1.bias                    | [192]                | 192
# blocks.3.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.3.mlp.fc2.bias                    | [96]                 | 96
# blocks.4.norm1.weight                    | [96]                 | 96
# blocks.4.norm1.bias                      | [96]                 | 96
# blocks.4.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.4.attn.qkv.bias                   | [288]                | 288
# blocks.4.attn.proj.weight                | [96, 96]             | 9216
# blocks.4.attn.proj.bias                  | [96]                 | 96
# blocks.4.norm2.weight                    | [96]                 | 96
# blocks.4.norm2.bias                      | [96]                 | 96
# blocks.4.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.4.mlp.fc1.bias                    | [192]                | 192
# blocks.4.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.4.mlp.fc2.bias                    | [96]                 | 96
# blocks.5.norm1.weight                    | [96]                 | 96
# blocks.5.norm1.bias                      | [96]                 | 96
# blocks.5.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.5.attn.qkv.bias                   | [288]                | 288
# blocks.5.attn.proj.weight                | [96, 96]             | 9216
# blocks.5.attn.proj.bias                  | [96]                 | 96
# blocks.5.norm2.weight                    | [96]                 | 96
# blocks.5.norm2.bias                      | [96]                 | 96
# blocks.5.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.5.mlp.fc1.bias                    | [192]                | 192
# blocks.5.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.5.mlp.fc2.bias                    | [96]                 | 96
# blocks.6.norm1.weight                    | [96]                 | 96
# blocks.6.norm1.bias                      | [96]                 | 96
# blocks.6.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.6.attn.qkv.bias                   | [288]                | 288
# blocks.6.attn.proj.weight                | [96, 96]             | 9216
# blocks.6.attn.proj.bias                  | [96]                 | 96
# blocks.6.norm2.weight                    | [96]                 | 96
# blocks.6.norm2.bias                      | [96]                 | 96
# blocks.6.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.6.mlp.fc1.bias                    | [192]                | 192
# blocks.6.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.6.mlp.fc2.bias                    | [96]                 | 96
# blocks.7.norm1.weight                    | [96]                 | 96
# blocks.7.norm1.bias                      | [96]                 | 96
# blocks.7.attn.qkv.weight                 | [288, 96]            | 27648
# blocks.7.attn.qkv.bias                   | [288]                | 288
# blocks.7.attn.proj.weight                | [96, 96]             | 9216
# blocks.7.attn.proj.bias                  | [96]                 | 96
# blocks.7.norm2.weight                    | [96]                 | 96
# blocks.7.norm2.bias                      | [96]                 | 96
# blocks.7.mlp.fc1.weight                  | [192, 96]            | 18432
# blocks.7.mlp.fc1.bias                    | [192]                | 192
# blocks.7.mlp.fc2.weight                  | [96, 192]            | 18432
# blocks.7.mlp.fc2.bias                    | [96]                 | 96
# norm.weight                              | [96]                 | 96
# norm.bias                                | [96]                 | 96
# head.weight                              | [200, 96]            | 19200
# head.bias                                | [200]                | 200
# --------------------------------------------------------------------------------
# Total Parameters Written: 642728
# File Size: 2510.66 KB
